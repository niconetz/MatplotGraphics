# %% [markdown]
# # Graficos en Matplot

# %% [markdown]
# ## bibliotecas
# Para hacer graficos en dos dimensiones de una función, se requiere importar las bibliotecas numpy, scipy y matplotlib, de esta ultima, en especifico el modulo pyplot.

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %% [markdown]
# Ahora, se determina en un vector 'x', el intervalo para el cual se va a evaluar la funcion, para esto se ocupa la funcion linspace que genera un vector con varios elementos en un intervalo.
#
# Linspace toma 3 argumentos, el valor inicial, el valor final y la cantidad de elementos que habrán en el intervalo igualmente espaciado.
#
# Ahora, se puede definir una funcion, con la sintaxis de python.
#
# Luego, usando la biblioteca de matplot, le indicamos que grafique, hay un montón de comandos extra que se detallan junto a su linea de codico como un comentario.

# %%
x=np.linspace(0,10,100)

def f(x):
    return 2*x + 1 + np.sin(x) + x**(0.0005) + np.cos(x+3) + np.exp(x**(0.01))


plt.plot(x,f(x))
plt.title('Mi primer Grafico')
plt.show()

# %% [markdown]
# # Guia de Uso de Matplot
#
# Aquí, se programa de una forma más orientada a objetos que en la forma anterior donde solo se llamaba a las funciones respectivas.
# Se declara el objeto fig que contiene ax, donde fig es la figura y ax es el area donde los puntos pueden relacionase.

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %% [markdown]
# ### Axes
# This is what you think of as 'a plot', it is the region of the image with the data space. A given figure can contain many Axes, but a given Axes object can only be in one Figure. The Axes contains two (or three in the case of 3D) Axis objects (be aware of the difference between Axes and Axis) which take care of the data limits (the data limits can also be controlled via the axes.Axes.set_xlim() and axes.Axes.set_ylim() methods). Each Axes has a title (set via set_title()), an x-label (set via set_xlabel()), and a y-label set via set_ylabel()).
#
# The Axes class and its member functions are the primary entry point to working with the OO interface.
#
# ### Axis
# These are the number-line-like objects. They take care of setting the graph limits and generating the ticks (the marks on the axis) and ticklabels (strings labeling the ticks). The location of the ticks is determined by a Locator object and the ticklabel strings are formatted by a Formatter. The combination of the correct Locator and Formatter gives very fine control over the tick locations and labels.

# %% [markdown]
# ## Otro ejemplo
# Graficando
#
# $$
# f(x) = 2x\\
# g(x) = x^{2}\\
# h(x) = ln(x)\\
# i(x) = \cos (6x)
#
# $$

# %%
#Graficarems las funciones en el intervalo -2,2
x=np.linspace(-2,2,100)

def f(x):
    return 2*x
def g(x):
    return x**2
def h(x):
    return np.log(x) #notar que esta definido para x>0
def i(x):
    return np.cos(6*x)

# consideramos las figuras en su forma de object oriented
#declaramos el nombre de la figura y del axes

figura1,ax1 = plt.subplots()
#se le dice que en el ax1, ponga el grafico de x, f(x)
ax1.plot(x,f(x),'--',label='2x')
ax1.plot(x,g(x),label='Cuadratica')
ax1.plot(x,h(x),label='log e')
ax1.plot(x,i(x),label='cos')

ax1.set_xlabel('x label')  # Add an x-label to the axes.
ax1.set_ylabel('y label')  # Add a y-label to the axes.
ax1.set_title("$f(x)=2x$")  # Add a title to the axes.

ax1.legend()  # Add a legend.
ax1.grid() # Añade la grilla?

# %% [markdown]
# ## Varios graficos en una figura

# %%
figura2, ax2 =plt.subplots(2,2)

# Se indica con [] y las posiciones en el array, a que axes nos estamos refiriendo.
ax2[0,0].plot(x,f(x)) 
ax2[1,0].plot(x,g(x))
ax2[0,1].plot(x,h(x))
ax2[1,1].plot(x,i(x))

ax2[0,0].set_title("grafico0,0")
ax2[1,1].set_title("grafico1,1") 
#el siguiente comando permite dar una mayor separacion entre los graficos 
#por lo tanto permite poner correctamente los titulos.
figura2.tight_layout()

# %% [markdown]
# ## Funciones utilizadas en el plot de Optimizacion
#
# En el archivo Optimizacion2, se utilizan funciones que no definí anteriormente, como por ejemplo:
# - x_size, y_size = 11, 16 : Indica el tamaño de los ejes ccoordenados?
# - plt.fill_between : se indica donde rellenar con un color especifico el area entre dos funciones
# -
